# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkapatwa/CSCI-167/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-vli0nixk
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-vli0nixk
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=0eb2333b872898cace97da3ebcc5e6c75fbc087ce11020822bfe4e9c2be634cf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1xbxwqux/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions


  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()

  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.298159, train error 88.97,  test loss 2.299042, test error 88.82
# Epoch   100, train loss 1.924614, train error 71.28,  test loss 1.766839, test error 69.80
# Epoch   200, train loss 1.914280, train error 72.47,  test loss 1.746171, test error 68.38
# Epoch   300, train loss 1.913979, train error 72.78,  test loss 1.742028, test error 69.43
# Epoch   400, train loss 1.913794, train error 71.12,  test loss 1.736849, test error 68.60
# Epoch   500, train loss 1.910899, train error 72.28,  test loss 1.742926, test error 69.47
# Epoch   600, train loss 1.907097, train error 71.88,  test loss 1.729959, test error 68.65
# Epoch   700, train loss 1.908379, train error 71.05,  test loss 1.732660, test error 69.15
# Epoch   800, train loss 1.911372, train error 71.95,  test loss 1.734181, test error 68.15
# Epoch   900, train loss 1.911625, train error 71.75,  test loss 1.739869, test error 69.28
# Training model with   4 hidden variables
# Epoch     0, train loss 2.308004, train error 89.78,  test loss 2.307934, test error 89.18
# Epoch   100, train loss 1.800194, train error 68.10,  test loss 1.646506, test error 65.10
# Epoch   200, train loss 1.755854, train error 65.07,  test loss 1.592870, test error 62.92
# Epoch   300, train loss 1.747517, train error 64.95,  test loss 1.605543, test error 62.45
# Epoch   400, train loss 1.750043, train error 64.75,  test loss 1.610314, test error 62.85
# Epoch   500, train loss 1.740108, train error 65.00,  test loss 1.602396, test error 62.60
# Epoch   600, train loss 1.741091, train error 65.22,  test loss 1.608059, test error 62.40
# Epoch   700, train loss 1.741075, train error 64.93,  test loss 1.606951, test error 62.05
# Epoch   800, train loss 1.736706, train error 64.47,  test loss 1.600581, test error 61.97
# Epoch   900, train loss 1.740262, train error 64.22,  test loss 1.608602, test error 62.25
# Training model with   6 hidden variables
# Epoch     0, train loss 2.300706, train error 89.30,  test loss 2.303705, test error 89.57
# Epoch   100, train loss 1.696411, train error 61.70,  test loss 1.474481, test error 57.53
# Epoch   200, train loss 1.681239, train error 59.58,  test loss 1.479942, test error 56.88
# Epoch   300, train loss 1.671112, train error 60.05,  test loss 1.484839, test error 58.15
# Epoch   400, train loss 1.660857, train error 58.92,  test loss 1.490349, test error 58.45
# Epoch   500, train loss 1.652108, train error 58.25,  test loss 1.486982, test error 58.40
# Epoch   600, train loss 1.645905, train error 58.95,  test loss 1.491661, test error 58.22
# Epoch   700, train loss 1.634602, train error 58.58,  test loss 1.490650, test error 57.97
# Epoch   800, train loss 1.642554, train error 59.28,  test loss 1.491373, test error 58.55
# Epoch   900, train loss 1.641698, train error 59.20,  test loss 1.497645, test error 58.38
# Training model with   8 hidden variables
# Epoch     0, train loss 2.283428, train error 84.18,  test loss 2.294321, test error 85.20
# Epoch   100, train loss 1.625561, train error 57.75,  test loss 1.475130, test error 57.00
# Epoch   200, train loss 1.599375, train error 56.45,  test loss 1.454287, test error 55.47
# Epoch   300, train loss 1.586492, train error 56.60,  test loss 1.450574, test error 55.90
# Epoch   400, train loss 1.578647, train error 55.65,  test loss 1.455649, test error 56.17
# Epoch   500, train loss 1.579348, train error 56.20,  test loss 1.465643, test error 57.03
# Epoch   600, train loss 1.569698, train error 55.72,  test loss 1.472687, test error 56.38
# Epoch   700, train loss 1.570658, train error 54.88,  test loss 1.480843, test error 56.47
# Epoch   800, train loss 1.566377, train error 54.83,  test loss 1.480705, test error 55.85
# Epoch   900, train loss 1.567287, train error 54.70,  test loss 1.484150, test error 55.58
# Training model with  10 hidden variables
# Epoch     0, train loss 2.210600, train error 81.43,  test loss 2.194181, test error 80.93
# Epoch   100, train loss 1.562347, train error 54.33,  test loss 1.426003, test error 54.53
# Epoch   200, train loss 1.481390, train error 51.08,  test loss 1.358730, test error 51.53
# Epoch   300, train loss 1.430432, train error 48.53,  test loss 1.291426, test error 48.15
# Epoch   400, train loss 1.411182, train error 48.50,  test loss 1.299396, test error 47.17
# Epoch   500, train loss 1.400841, train error 48.62,  test loss 1.296191, test error 47.47
# Epoch   600, train loss 1.398164, train error 48.42,  test loss 1.299383, test error 47.78
# Epoch   700, train loss 1.393014, train error 48.33,  test loss 1.302420, test error 48.17
# Epoch   800, train loss 1.390232, train error 48.50,  test loss 1.306115, test error 48.40
# Epoch   900, train loss 1.387663, train error 47.72,  test loss 1.323722, test error 48.35
# Training model with  14 hidden variables
# Epoch     0, train loss 2.174869, train error 80.50,  test loss 2.132345, test error 80.65
# Epoch   100, train loss 1.383896, train error 45.85,  test loss 1.254467, test error 45.83
# Epoch   200, train loss 1.332654, train error 44.22,  test loss 1.273870, test error 47.58
# Epoch   300, train loss 1.295075, train error 42.72,  test loss 1.275149, test error 46.62
# Epoch   400, train loss 1.290496, train error 43.50,  test loss 1.317975, test error 47.90
# Epoch   500, train loss 1.268829, train error 42.10,  test loss 1.337012, test error 48.20
# Epoch   600, train loss 1.256937, train error 41.75,  test loss 1.362806, test error 48.33
# Epoch   700, train loss 1.256885, train error 41.72,  test loss 1.387740, test error 48.15
# Epoch   800, train loss 1.247538, train error 42.03,  test loss 1.403045, test error 48.50
# Epoch   900, train loss 1.249920, train error 42.40,  test loss 1.422079, test error 48.80
# Training model with  18 hidden variables
# Epoch     0, train loss 2.174825, train error 81.90,  test loss 2.148358, test error 79.53
# Epoch   100, train loss 1.350887, train error 45.47,  test loss 1.261580, test error 46.65
# Epoch   200, train loss 1.239663, train error 41.40,  test loss 1.283543, test error 47.25
# Epoch   300, train loss 1.207190, train error 41.28,  test loss 1.329027, test error 48.15
# Epoch   400, train loss 1.192059, train error 40.12,  test loss 1.357444, test error 48.97
# Epoch   500, train loss 1.162235, train error 39.55,  test loss 1.372157, test error 48.47
# Epoch   600, train loss 1.151814, train error 39.22,  test loss 1.421657, test error 49.53
# Epoch   700, train loss 1.135281, train error 38.72,  test loss 1.444124, test error 49.53
# Epoch   800, train loss 1.131877, train error 38.10,  test loss 1.461368, test error 49.50
# Epoch   900, train loss 1.118254, train error 38.12,  test loss 1.466686, test error 49.38
# Training model with  22 hidden variables
# Epoch     0, train loss 2.187463, train error 80.82,  test loss 2.188206, test error 81.78
# Epoch   100, train loss 1.264208, train error 42.03,  test loss 1.343533, test error 51.15
# Epoch   200, train loss 1.128202, train error 37.80,  test loss 1.431585, test error 51.40
# Epoch   300, train loss 1.076248, train error 36.05,  test loss 1.545289, test error 51.12
# Epoch   400, train loss 1.046207, train error 35.70,  test loss 1.616468, test error 51.72
# Epoch   500, train loss 1.014253, train error 34.25,  test loss 1.672236, test error 52.55
# Epoch   600, train loss 1.005349, train error 34.35,  test loss 1.752938, test error 52.72
# Epoch   700, train loss 0.984873, train error 34.25,  test loss 1.770836, test error 52.58
# Epoch   800, train loss 0.973679, train error 33.03,  test loss 1.808692, test error 52.92
# Epoch   900, train loss 0.954063, train error 32.53,  test loss 1.830770, test error 53.97
# Training model with  26 hidden variables
# Epoch     0, train loss 2.138323, train error 79.47,  test loss 2.093522, test error 77.68
# Epoch   100, train loss 1.161328, train error 38.42,  test loss 1.287857, test error 47.60
# Epoch   200, train loss 1.028220, train error 34.72,  test loss 1.375956, test error 47.97
# Epoch   300, train loss 0.963125, train error 32.22,  test loss 1.536570, test error 49.83
# Epoch   400, train loss 0.915261, train error 31.05,  test loss 1.700632, test error 51.15
# Epoch   500, train loss 0.881000, train error 29.72,  test loss 1.782722, test error 51.30
# Epoch   600, train loss 0.847431, train error 28.78,  test loss 1.845777, test error 51.50
# Epoch   700, train loss 0.825415, train error 28.00,  test loss 1.935517, test error 52.25
# Epoch   800, train loss 0.817997, train error 28.22,  test loss 2.042426, test error 52.12
# Epoch   900, train loss 0.803507, train error 28.40,  test loss 2.135600, test error 53.72
# Training model with  30 hidden variables
# Epoch     0, train loss 2.134110, train error 80.68,  test loss 2.098369, test error 79.35
# Epoch   100, train loss 1.112229, train error 35.35,  test loss 1.316499, test error 47.15
# Epoch   200, train loss 0.918156, train error 29.97,  test loss 1.450282, test error 49.03
# Epoch   300, train loss 0.832241, train error 27.78,  test loss 1.673946, test error 51.40
# Epoch   400, train loss 0.787525, train error 26.70,  test loss 1.893049, test error 52.47
# Epoch   500, train loss 0.744668, train error 25.55,  test loss 2.073870, test error 52.78
# Epoch   600, train loss 0.716067, train error 24.53,  test loss 2.199357, test error 52.97
# Epoch   700, train loss 0.686412, train error 24.03,  test loss 2.320811, test error 53.42
# Epoch   800, train loss 0.686143, train error 23.80,  test loss 2.456126, test error 54.35
# Epoch   900, train loss 0.666236, train error 23.03,  test loss 2.650656, test error 55.40
# Training model with  35 hidden variables
# Epoch     0, train loss 2.156220, train error 79.70,  test loss 2.142339, test error 80.03
# Epoch   100, train loss 1.029074, train error 34.05,  test loss 1.357319, test error 48.12
# Epoch   200, train loss 0.823146, train error 27.43,  test loss 1.636886, test error 50.70
# Epoch   300, train loss 0.706364, train error 23.90,  test loss 1.995954, test error 53.35
# Epoch   400, train loss 0.627293, train error 21.05,  test loss 2.331224, test error 53.88
# Epoch   500, train loss 0.598899, train error 20.82,  test loss 2.748499, test error 56.40
# Epoch   600, train loss 0.534435, train error 17.97,  test loss 3.056209, test error 57.08
# Epoch   700, train loss 0.524899, train error 18.10,  test loss 3.411721, test error 57.40
# Epoch   800, train loss 0.487437, train error 17.32,  test loss 3.733739, test error 57.15
# Epoch   900, train loss 0.456611, train error 15.82,  test loss 4.018114, test error 56.88
# Training model with  40 hidden variables
# Epoch     0, train loss 2.107428, train error 79.12,  test loss 2.059650, test error 78.53
# Epoch   100, train loss 0.903385, train error 29.45,  test loss 1.413117, test error 48.05
# Epoch   200, train loss 0.638385, train error 20.75,  test loss 1.923935, test error 52.85
# Epoch   300, train loss 0.517371, train error 17.22,  test loss 2.616293, test error 54.03
# Epoch   400, train loss 0.391323, train error 12.95,  test loss 3.274561, test error 55.42
# Epoch   500, train loss 0.309068, train error 9.75,  test loss 4.040470, test error 56.05
# Epoch   600, train loss 0.293485, train error 10.10,  test loss 4.808240, test error 56.42
# Epoch   700, train loss 0.231521, train error 7.20,  test loss 5.545245, test error 56.22
# Epoch   800, train loss 0.283747, train error 10.05,  test loss 6.330516, test error 57.08
# Epoch   900, train loss 0.220962, train error 8.05,  test loss 7.049806, test error 57.35
# Training model with  45 hidden variables
# Epoch     0, train loss 2.107398, train error 77.57,  test loss 2.047887, test error 76.47
# Epoch   100, train loss 0.800359, train error 24.78,  test loss 1.441835, test error 48.08
# Epoch   200, train loss 0.492896, train error 15.00,  test loss 2.184600, test error 52.45
# Epoch   300, train loss 0.330238, train error 10.45,  test loss 3.226535, test error 55.50
# Epoch   400, train loss 0.260839, train error 8.20,  test loss 4.619946, test error 56.30
# Epoch   500, train loss 0.188858, train error 6.57,  test loss 5.926376, test error 55.88
# Epoch   600, train loss 0.186235, train error 6.57,  test loss 7.087072, test error 56.20
# Epoch   700, train loss 0.014984, train error 0.00,  test loss 8.178471, test error 56.28
# Epoch   800, train loss 0.008546, train error 0.00,  test loss 8.982188, test error 56.05
# Epoch   900, train loss 0.006228, train error 0.00,  test loss 9.527614, test error 56.22
# Training model with  50 hidden variables
# Epoch     0, train loss 2.057225, train error 76.05,  test loss 2.025189, test error 75.85
# Epoch   100, train loss 0.677484, train error 20.43,  test loss 1.580959, test error 50.00
# Epoch   200, train loss 0.343930, train error 9.95,  test loss 2.669756, test error 53.08
# Epoch   300, train loss 0.158775, train error 3.75,  test loss 4.187480, test error 54.17
# Epoch   400, train loss 0.030580, train error 0.03,  test loss 5.819201, test error 55.22
# Epoch   500, train loss 0.013858, train error 0.00,  test loss 6.830691, test error 55.35
# Epoch   600, train loss 0.008587, train error 0.00,  test loss 7.489092, test error 55.33
# Epoch   700, train loss 0.006173, train error 0.00,  test loss 7.974843, test error 55.40
# Epoch   800, train loss 0.004777, train error 0.00,  test loss 8.363357, test error 55.47
# Epoch   900, train loss 0.003838, train error 0.00,  test loss 8.697662, test error 55.78
# Training model with  55 hidden variables
# Epoch     0, train loss 2.038086, train error 75.90,  test loss 1.971792, test error 75.60
# Epoch   100, train loss 0.621217, train error 18.50,  test loss 1.660295, test error 52.58
# Epoch   200, train loss 0.254490, train error 7.20,  test loss 3.000840, test error 54.03
# Epoch   300, train loss 0.040417, train error 0.07,  test loss 4.550123, test error 54.92
# Epoch   400, train loss 0.014422, train error 0.00,  test loss 5.543605, test error 54.95
# Epoch   500, train loss 0.008461, train error 0.00,  test loss 6.144143, test error 55.03
# Epoch   600, train loss 0.005761, train error 0.00,  test loss 6.570141, test error 55.05
# Epoch   700, train loss 0.004300, train error 0.00,  test loss 6.895424, test error 54.97
# Epoch   800, train loss 0.003392, train error 0.00,  test loss 7.161641, test error 55.05
# Epoch   900, train loss 0.002780, train error 0.00,  test loss 7.389225, test error 55.08
# Training model with  60 hidden variables
# Epoch     0, train loss 2.085787, train error 78.32,  test loss 2.023302, test error 76.22
# Epoch   100, train loss 0.531028, train error 15.38,  test loss 1.740912, test error 51.53
# Epoch   200, train loss 0.097005, train error 0.90,  test loss 3.400311, test error 53.35
# Epoch   300, train loss 0.020119, train error 0.00,  test loss 4.681039, test error 53.58
# Epoch   400, train loss 0.009747, train error 0.00,  test loss 5.372432, test error 53.58
# Epoch   500, train loss 0.006172, train error 0.00,  test loss 5.831327, test error 53.67
# Epoch   600, train loss 0.004413, train error 0.00,  test loss 6.161607, test error 53.70
# Epoch   700, train loss 0.003368, train error 0.00,  test loss 6.430197, test error 53.62
# Epoch   800, train loss 0.002711, train error 0.00,  test loss 6.650610, test error 53.60
# Epoch   900, train loss 0.002254, train error 0.00,  test loss 6.840911, test error 53.67
# Training model with  70 hidden variables
# Epoch     0, train loss 2.034306, train error 74.88,  test loss 1.997622, test error 75.85
# Epoch   100, train loss 0.360197, train error 8.60,  test loss 1.981526, test error 52.28
# Epoch   200, train loss 0.029706, train error 0.00,  test loss 3.620699, test error 52.17
# Epoch   300, train loss 0.010413, train error 0.00,  test loss 4.380809, test error 52.38
# Epoch   400, train loss 0.005872, train error 0.00,  test loss 4.816083, test error 52.42
# Epoch   500, train loss 0.003966, train error 0.00,  test loss 5.118104, test error 52.38
# Epoch   600, train loss 0.002948, train error 0.00,  test loss 5.347805, test error 52.50
# Epoch   700, train loss 0.002315, train error 0.00,  test loss 5.532473, test error 52.55
# Epoch   800, train loss 0.001893, train error 0.00,  test loss 5.689085, test error 52.62
# Epoch   900, train loss 0.001592, train error 0.00,  test loss 5.824454, test error 52.62
# Training model with  80 hidden variables
# Epoch     0, train loss 2.002285, train error 74.90,  test loss 1.939998, test error 74.53
# Epoch   100, train loss 0.208215, train error 2.70,  test loss 2.133384, test error 51.35
# Epoch   200, train loss 0.018772, train error 0.00,  test loss 3.449849, test error 52.30
# Epoch   300, train loss 0.007806, train error 0.00,  test loss 3.995742, test error 52.55
# Epoch   400, train loss 0.004608, train error 0.00,  test loss 4.316153, test error 52.67
# Epoch   500, train loss 0.003199, train error 0.00,  test loss 4.545747, test error 52.65
# Epoch   600, train loss 0.002417, train error 0.00,  test loss 4.719288, test error 52.78
# Epoch   700, train loss 0.001922, train error 0.00,  test loss 4.865681, test error 52.83
# Epoch   800, train loss 0.001584, train error 0.00,  test loss 4.988675, test error 52.95
# Epoch   900, train loss 0.001340, train error 0.00,  test loss 5.095338, test error 52.88
# Training model with  90 hidden variables
# Epoch     0, train loss 1.985859, train error 73.72,  test loss 1.938263, test error 75.43
# Epoch   100, train loss 0.136606, train error 0.80,  test loss 2.296862, test error 52.90
# Epoch   200, train loss 0.014953, train error 0.00,  test loss 3.453809, test error 53.67
# Epoch   300, train loss 0.006617, train error 0.00,  test loss 3.923893, test error 53.65
# Epoch   400, train loss 0.004010, train error 0.00,  test loss 4.205906, test error 53.78
# Epoch   500, train loss 0.002818, train error 0.00,  test loss 4.410172, test error 53.67
# Epoch   600, train loss 0.002146, train error 0.00,  test loss 4.570311, test error 53.65
# Epoch   700, train loss 0.001717, train error 0.00,  test loss 4.702587, test error 53.75
# Epoch   800, train loss 0.001421, train error 0.00,  test loss 4.813508, test error 53.85
# Epoch   900, train loss 0.001206, train error 0.00,  test loss 4.910599, test error 53.83
# Training model with 100 hidden variables
# Epoch     0, train loss 1.986147, train error 73.72,  test loss 1.926641, test error 73.82
# Epoch   100, train loss 0.092315, train error 0.18,  test loss 2.214311, test error 50.20
# Epoch   200, train loss 0.012315, train error 0.00,  test loss 3.106035, test error 51.45
# Epoch   300, train loss 0.005688, train error 0.00,  test loss 3.474944, test error 51.50
# Epoch   400, train loss 0.003545, train error 0.00,  test loss 3.702399, test error 51.58
# Epoch   500, train loss 0.002520, train error 0.00,  test loss 3.868341, test error 51.55
# Epoch   600, train loss 0.001931, train error 0.00,  test loss 3.997193, test error 51.53
# Epoch   700, train loss 0.001551, train error 0.00,  test loss 4.105704, test error 51.47
# Epoch   800, train loss 0.001289, train error 0.00,  test loss 4.197241, test error 51.45
# Epoch   900, train loss 0.001098, train error 0.00,  test loss 4.276648, test error 51.42
# Training model with 120 hidden variables
# Epoch     0, train loss 1.977388, train error 73.10,  test loss 1.917526, test error 74.28
# Epoch   100, train loss 0.048386, train error 0.00,  test loss 2.227350, test error 50.10
# Epoch   200, train loss 0.009191, train error 0.00,  test loss 2.826080, test error 49.88
# Epoch   300, train loss 0.004590, train error 0.00,  test loss 3.100981, test error 50.00
# Epoch   400, train loss 0.002939, train error 0.00,  test loss 3.279557, test error 49.78
# Epoch   500, train loss 0.002126, train error 0.00,  test loss 3.409867, test error 49.83
# Epoch   600, train loss 0.001645, train error 0.00,  test loss 3.514875, test error 49.85
# Epoch   700, train loss 0.001330, train error 0.00,  test loss 3.601692, test error 49.85
# Epoch   800, train loss 0.001111, train error 0.00,  test loss 3.675303, test error 49.92
# Epoch   900, train loss 0.000950, train error 0.00,  test loss 3.739196, test error 49.95
# Training model with 140 hidden variables
# Epoch     0, train loss 1.952414, train error 71.60,  test loss 1.897706, test error 73.15
# Epoch   100, train loss 0.035478, train error 0.00,  test loss 2.142128, test error 49.62
# Epoch   200, train loss 0.007889, train error 0.00,  test loss 2.610271, test error 49.70
# Epoch   300, train loss 0.004061, train error 0.00,  test loss 2.835022, test error 49.45
# Epoch   400, train loss 0.002646, train error 0.00,  test loss 2.983394, test error 49.38
# Epoch   500, train loss 0.001928, train error 0.00,  test loss 3.093046, test error 49.42
# Epoch   600, train loss 0.001500, train error 0.00,  test loss 3.180657, test error 49.45
# Epoch   700, train loss 0.001219, train error 0.00,  test loss 3.252592, test error 49.40
# Epoch   800, train loss 0.001020, train error 0.00,  test loss 3.314690, test error 49.55
# Epoch   900, train loss 0.000874, train error 0.00,  test loss 3.368606, test error 49.47
# Training model with 160 hidden variables
# Epoch     0, train loss 1.931768, train error 70.65,  test loss 1.867146, test error 72.45
# Epoch   100, train loss 0.028329, train error 0.00,  test loss 2.109315, test error 48.10
# Epoch   200, train loss 0.007146, train error 0.00,  test loss 2.522983, test error 48.42
# Epoch   300, train loss 0.003765, train error 0.00,  test loss 2.723847, test error 48.28
# Epoch   400, train loss 0.002475, train error 0.00,  test loss 2.858572, test error 48.33
# Epoch   500, train loss 0.001814, train error 0.00,  test loss 2.958699, test error 48.50
# Epoch   600, train loss 0.001416, train error 0.00,  test loss 3.039666, test error 48.55
# Epoch   700, train loss 0.001154, train error 0.00,  test loss 3.107119, test error 48.60
# Epoch   800, train loss 0.000969, train error 0.00,  test loss 3.164160, test error 48.62
# Epoch   900, train loss 0.000831, train error 0.00,  test loss 3.214593, test error 48.70
# Training model with 180 hidden variables
# Epoch     0, train loss 1.926208, train error 70.95,  test loss 1.869332, test error 71.07
# Epoch   100, train loss 0.024411, train error 0.00,  test loss 2.128047, test error 48.90
# Epoch   200, train loss 0.006531, train error 0.00,  test loss 2.499712, test error 48.65
# Epoch   300, train loss 0.003510, train error 0.00,  test loss 2.690317, test error 48.58
# Epoch   400, train loss 0.002320, train error 0.00,  test loss 2.815475, test error 48.70
# Epoch   500, train loss 0.001707, train error 0.00,  test loss 2.910615, test error 48.75
# Epoch   600, train loss 0.001336, train error 0.00,  test loss 2.986091, test error 48.92
# Epoch   700, train loss 0.001090, train error 0.00,  test loss 3.048587, test error 48.85
# Epoch   800, train loss 0.000917, train error 0.00,  test loss 3.103005, test error 48.83
# Epoch   900, train loss 0.000788, train error 0.00,  test loss 3.149956, test error 48.88
# Training model with 200 hidden variables
# Epoch     0, train loss 1.926638, train error 71.20,  test loss 1.839949, test error 72.43
# Epoch   100, train loss 0.021422, train error 0.00,  test loss 1.995269, test error 48.40
# Epoch   200, train loss 0.006146, train error 0.00,  test loss 2.304806, test error 48.50

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
